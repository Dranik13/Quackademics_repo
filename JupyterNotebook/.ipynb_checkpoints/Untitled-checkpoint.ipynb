# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ZUyvS9QdMs5yBJyz0JA3")
project = rf.workspace("robogistics-hagpe").project("duckietown-duckies-4ew0a")
version = project.version(4)
dataset = version.download("yolov11")
# Out:
# Requirement already satisfied: roboflow in /home/dennis/anaconda3/lib/python3.12/site-packages (1.1.63)
# Requirement already satisfied: certifi in /home/dennis/anaconda3/lib/python3.12/site-packages (from roboflow) (2024.8.30)
# Requirement already satisfied: idna==3.7 in /home/dennis/anaconda3/lib/python3.12/site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /home/dennis/anaconda3/lib/python3.12/site-packages (from roboflow) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/dennis/anaconda3/lib/python3.12/site-packages (from roboflow) (1.4.4)
# Requirement already satisfied: matplotlib in /home/dennis/anaconda3/lib/python3.12/site-packages (from roboflow) (3.9.2)
# Requirement already satisfied: numpy>=1.18.5 in /home/dennis/anaconda3/lib/python3.12/site-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /home/dennis/anaconda3/lib/python3.12/site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /home/dennis/anaconda3/lib/python3.12/site-packages (from roboflow) (10.4.0)
# Requirement already satisfied: pillow-heif>=0.18.0 in /home/dennis/anaconda3/lib/python3.12/site-packages (from roboflow) (0.22.0)
# Requirement already satisfied: python-dateutil in /home/dennis/anaconda3/lib/python3.12/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /home/dennis/anaconda3/lib/python3.12/site-packages (from roboflow) (0.21.0)
# Requirement already satisfied: requests in /home/dennis/.local/lib/python3.12/site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /home/dennis/anaconda3/lib/python3.12/site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /home/dennis/anaconda3/lib/python3.12/site-packages (from roboflow) (2.2.3)
# Requirement already satisfied: tqdm>=4.41.0 in /home/dennis/anaconda3/lib/python3.12/site-packages (from roboflow) (4.66.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/dennis/anaconda3/lib/python3.12/site-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /home/dennis/anaconda3/lib/python3.12/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /home/dennis/anaconda3/lib/python3.12/site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/dennis/anaconda3/lib/python3.12/site-packages (from matplotlib->roboflow) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/dennis/anaconda3/lib/python3.12/site-packages (from matplotlib->roboflow) (4.51.0)
# Requirement already satisfied: packaging>=20.0 in /home/dennis/anaconda3/lib/python3.12/site-packages (from matplotlib->roboflow) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/dennis/anaconda3/lib/python3.12/site-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/dennis/anaconda3/lib/python3.12/site-packages (from requests->roboflow) (3.3.2)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Duckietown-Duckies-4 to yolov11:: 100%|█| 898
# Extracting Dataset Version Zip to Duckietown-Duckies-4 in yolov11:: 100%|█| 4508

# %%
# Voraussetzung: Installation der Ultralytics-Bibliothek (YOLOv11)
# Installieren (falls noch nicht vorhanden):
# !pip install ultralytics

from ultralytics import YOLO

# === Schritt 1: Modell laden ===
model = YOLO('yolo11n.pt')  # Verwende YOLOv11 Nano (leichtes Modell für Edge Devices)

# === Schritt 2: Training starten ===
model.train(
    data='data.yaml',     # Pfad zu deiner data.yaml-Datei
    epochs=50,            # Anzahl der Epochen
    imgsz=416,            # Eingabebildgröße (416x416 schneller als 640)
    batch=16,             # Batch-Größe
    name='duckie11_train', # Name des Runs / Ausgabeordners
    device = 0
)

# === Schritt 3: Exportiere bestes Modell als ONNX ===
model.export(
    format='onnx',  # Export-Format
    dynamic=True,   # Erlaubt variable Eingabegrößen
    simplify=True   # Optimiert das ONNX-Modell
)

print("✅ Training abgeschlossen und Modell als ONNX exportiert.")
# Out:
# Requirement already satisfied: ultralytics in /home/dennis/anaconda3/lib/python3.12/site-packages (8.3.128)
# Requirement already satisfied: numpy>=1.23.0 in /home/dennis/anaconda3/lib/python3.12/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/dennis/anaconda3/lib/python3.12/site-packages (from ultralytics) (3.9.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/dennis/anaconda3/lib/python3.12/site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /home/dennis/anaconda3/lib/python3.12/site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/dennis/anaconda3/lib/python3.12/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /home/dennis/.local/lib/python3.12/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /home/dennis/anaconda3/lib/python3.12/site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /home/dennis/anaconda3/lib/python3.12/site-packages (from ultralytics) (2.7.0)
# Requirement already satisfied: torchvision>=0.9.0 in /home/dennis/anaconda3/lib/python3.12/site-packages (from ultralytics) (0.22.0)
# Requirement already satisfied: tqdm>=4.64.0 in /home/dennis/anaconda3/lib/python3.12/site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in /home/dennis/anaconda3/lib/python3.12/site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in /home/dennis/anaconda3/lib/python3.12/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /home/dennis/anaconda3/lib/python3.12/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /home/dennis/anaconda3/lib/python3.12/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /home/dennis/anaconda3/lib/python3.12/site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /home/dennis/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/dennis/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/dennis/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/dennis/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/dennis/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/dennis/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/dennis/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/dennis/anaconda3/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/dennis/anaconda3/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/dennis/anaconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/dennis/anaconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/dennis/anaconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/dennis/anaconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Requirement already satisfied: setuptools in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (75.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.3.0 in /home/dennis/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.3.0)
# Requirement already satisfied: six>=1.5 in /home/dennis/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/dennis/anaconda3/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/dennis/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Ultralytics 8.3.128 🚀 Python-3.12.7 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce 940MX, 1996MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=416, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=duckie11_train5, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/duckie11_train5, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.4±0.2 ms, read: 118.5±21.3 MB/s, size: 39.5 KB)
# train: Scanning /home/dennis/Duckietown/Quackademics_repo/JupyterNotebook/train/
# val: Fast image access ✅ (ping: 0.1±0.2 ms, read: 95.1±50.2 MB/s, size: 41.5 KB)
# val: Scanning /home/dennis/Duckietown/Quackademics_repo/JupyterNotebook/valid/la
# Plotting labels to runs/detect/duckie11_train5/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 416 train, 416 val
# Using 4 dataloader workers
# Logging results to runs/detect/duckie11_train5
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      1.73G      1.387      1.712     0.8872         80        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        366       1537      0.972      0.467      0.763      0.448
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      1.78G      1.293     0.9663     0.8821         87        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        366       1537      0.883      0.782      0.837      0.496
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      1.77G      1.241     0.8241     0.8734         69        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        366       1537      0.912      0.787       0.85      0.486
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      1.75G      1.235      0.743     0.8746        117        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        366       1537      0.921      0.792      0.867      0.505
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      1.75G      1.194     0.6965     0.8643         67        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        366       1537      0.921      0.794      0.881      0.527
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      1.75G      1.193     0.6552     0.8644         43        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        366       1537      0.922      0.831      0.896      0.557
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      1.76G       1.17     0.6333     0.8694         83        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        366       1537      0.927      0.845      0.906      0.556
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      1.77G      1.149     0.6046     0.8574         89        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        366       1537      0.925      0.835      0.901      0.556
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      1.76G      1.102     0.5718     0.8568         55        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        366       1537      0.922      0.843      0.907      0.555
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      1.76G      1.115     0.5828     0.8528         62        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        366       1537      0.914      0.838      0.897       0.57
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      1.77G      1.095     0.5707     0.8492        122        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        366       1537      0.896      0.861      0.907      0.578
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      1.76G      1.074      0.551     0.8553         40        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        366       1537      0.914      0.858      0.915      0.605
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      1.76G      1.092      0.557     0.8482         92        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        366       1537      0.916      0.852      0.917      0.566
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      1.75G      1.083     0.5496     0.8425         85        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        366       1537       0.92      0.859      0.921      0.599
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      1.76G      1.059     0.5348     0.8411         84        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        366       1537      0.916      0.844      0.908      0.588
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      1.75G      1.059      0.531     0.8437         77        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        366       1537      0.926      0.852      0.914      0.585
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      1.75G      1.042     0.5247     0.8384         49        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        366       1537      0.916      0.876      0.921      0.606
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      1.75G      1.038     0.5195     0.8426        170        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        366       1537       0.93      0.864      0.927      0.612
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      1.75G      1.037     0.5161      0.842         56        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        366       1537      0.913      0.872      0.925      0.624
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      1.75G      1.009     0.4975     0.8405         69        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        366       1537      0.926      0.862      0.917      0.613
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50

# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        366       1537      0.938      0.888      0.946      0.664
# Speed: 0.7ms preprocess, 11.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to runs/detect/duckie11_train5
# Ultralytics 8.3.128 🚀 Python-3.12.7 torch-2.7.0+cu126 CPU (Intel Core(TM) i5-7200U 2.50GHz)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'runs/detect/duckie11_train5/weights/best.pt' with input shape (1, 3, 416, 416) BCHW and output shape(s) (1, 5, 3549) (5.2 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim>=0.1.46', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# Collecting onnx>=1.12.0
#   Downloading onnx-1.17.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting onnxslim>=0.1.46
#   Downloading onnxslim-0.1.51-py3-none-any.whl.metadata (5.0 kB)
# Collecting onnxruntime-gpu
#   Downloading onnxruntime_gpu-1.21.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.20 in /home/dennis/anaconda3/lib/python3.12/site-packages (from onnx>=1.12.0) (1.26.4)
# Requirement already satisfied: protobuf>=3.20.2 in /home/dennis/anaconda3/lib/python3.12/site-packages (from onnx>=1.12.0) (4.25.3)
# Requirement already satisfied: sympy in /home/dennis/anaconda3/lib/python3.12/site-packages (from onnxslim>=0.1.46) (1.14.0)
# Requirement already satisfied: packaging in /home/dennis/anaconda3/lib/python3.12/site-packages (from onnxslim>=0.1.46) (24.1)
# Requirement already satisfied: coloredlogs in /home/dennis/.local/lib/python3.12/site-packages (from onnxruntime-gpu) (15.0.1)
# Collecting flatbuffers (from onnxruntime-gpu)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: humanfriendly>=9.1 in /home/dennis/.local/lib/python3.12/site-packages (from coloredlogs->onnxruntime-gpu) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/dennis/anaconda3/lib/python3.12/site-packages (from sympy->onnxslim>=0.1.46) (1.3.0)
# Downloading onnx-1.17.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 26.6 MB/s eta 0:00:0031m26.5 MB/s eta 0:00:01
# Downloading onnxslim-0.1.51-py3-none-any.whl (145 kB)
# Downloading onnxruntime_gpu-1.21.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (280.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.8/280.8 MB 17.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Installing collected packages: flatbuffers, onnx, onnxslim, onnxruntime-gpu
# Successfully installed flatbuffers-25.2.10 onnx-1.17.0 onnxruntime-gpu-1.21.1 onnxslim-0.1.51
#
# requirements: AutoUpdate success ✅ 25.9s, installed 3 packages: ['onnx>=1.12.0', 'onnxslim>=0.1.46', 'onnxruntime-gpu']
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.51...
# ONNX: export success ✅ 42.8s, saved as 'runs/detect/duckie11_train5/weights/best.onnx' (10.0 MB)
#
# Export complete (43.3s)
# Results saved to /home/dennis/Duckietown/Quackademics_repo/JupyterNotebook/runs/detect/duckie11_train5/weights
# Predict:         yolo predict task=detect model=runs/detect/duckie11_train5/weights/best.onnx imgsz=416
# Validate:        yolo val task=detect model=runs/detect/duckie11_train5/weights/best.onnx imgsz=416 data=data.yaml
# Visualize:       https://netron.app
# ✅ Training abgeschlossen und Modell als ONNX exportiert.

# %%
import torch

if torch.cuda.is_available():
    num_devices = torch.cuda.device_count()
    for i in range(num_devices):
        print(f"Device {i}: {torch.cuda.get_device_name(i)}")
else:
    print("❌ Keine CUDA-fähige GPU gefunden.")
# Out:
# Device 0: NVIDIA GeForce 940MX
